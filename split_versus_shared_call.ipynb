# %% [markdown]
# # Next Steps MGPGG

# %% [markdown]
# ## Next
# - Look at link Tristan sent about properly using a look-up table. See if I can implement this (finding difficulty)
# - parameterize
# - Run and look for differences between the ENDOWMENT treatments (be able to save multiple csv.s)
# - Decision Rules? (Alteration) (player types, type of randomness, strictness,)
# - Look at SCALE FACTOR (R) (I checked and the scaled public good & earnings are correct, but ppl are updating strangely)
# - Power Analysis
# - Visual component for looking at differences between coop OT with diff parameters
# - Convert outputs to % of endowment

# %% [markdown]
# # Import Utils

# %%
from src.plots import *

# %%
groups_example = formed_groups_matrix(GROUP_SIZE, NUM_GROUPS)
np.argwhere(groups_example == 1) # GOOD FOR VECTORIZING LATER; gives me indices of what groups ppl are in. Will no longer need to use for loop

# %% [markdown]
# ### Shared Endowment

# %%
SHARED = 1
shared_sim = monte_carlo_simulation(SIMS)

# %%
shared_sim
# Out:
#                 Round0     Round1     Round2     Round3     Round4     Round5  \
# Simulation0  23.437500  25.156250  23.937500  22.843750  20.531250  21.343750
# Simulation0  31.156250  36.593750  37.312500  37.031250  36.250000  35.000000
# Simulation0  27.000000  26.687500  26.250000  25.531250  24.843750  24.093750
# Simulation0  37.687500  37.875000  39.437500  40.718750  40.500000  39.531250
# Simulation0  28.156250  29.843750  30.718750  32.468750  33.843750  32.781250
# ...                ...        ...        ...        ...        ...        ...
# Simulation0  21.156250  24.093750  23.156250  23.281250  22.906250  22.656250
# Simulation0  25.968750  26.812500  28.250000  28.625000  28.312500  27.562500
# Simulation0  25.656250  27.718750  27.687500  27.500000  25.468750  25.375000
# Simulation0  29.781250  33.750000  34.656250  34.937500  32.968750  30.468750
# Round Mean   27.028406  28.364031  28.488781  28.073781  27.428062  26.632687
#
#                 Round6     Round7     Round8     Round9  ...    Round11  \
# Simulation0  21.687500  21.000000  20.375000  19.718750  ...  19.062500
# Simulation0  32.781250  31.156250  30.312500  29.093750  ...  27.187500
# Simulation0  21.968750  22.656250  21.250000  19.625000  ...  17.468750
# Simulation0  38.937500  38.218750  36.875000  36.062500  ...  36.281250
# Simulation0  32.625000  31.093750  30.312500  29.406250  ...  27.031250
# ...                ...        ...        ...        ...  ...        ...
# Simulation0  22.031250  19.406250  19.062500  19.375000  ...  17.906250
# Simulation0  27.031250  26.125000  24.500000  23.062500  ...  21.312500
# Simulation0  24.937500  24.062500  24.468750  22.687500  ...  22.312500
# Simulation0  28.343750  28.687500  26.281250  25.093750  ...  25.187500
# Round Mean   25.807344  24.898312  24.017563  23.102656  ...  21.498656
#
#                Round12    Round13    Round14   Round15   Round16    Round17  \
# Simulation0  18.375000  17.343750  17.687500  17.00000  16.50000  15.968750
# Simulation0  25.781250  24.750000  23.562500  21.68750  21.00000  20.500000
# Simulation0  16.468750  16.062500  14.968750  14.03125  13.21875  12.781250
# Simulation0  35.812500  35.343750  35.031250  34.31250  33.56250  32.531250
# Simulation0  26.093750  25.656250  24.500000  24.03125  23.75000  23.625000
# ...                ...        ...        ...       ...       ...        ...
# Simulation0  17.437500  16.812500  16.187500  16.37500  16.03125  15.500000
# Simulation0  20.312500  19.343750  18.500000  17.53125  17.68750  17.000000
# Simulation0  21.375000  21.250000  21.156250  20.71875  20.46875  20.187500
# Simulation0  24.718750  23.843750  22.718750  21.50000  20.15625  20.437500
# Round Mean   20.758469  20.048813  19.382375  18.80150  18.32475  17.929938
#
#                Round18    Round19  Simulation Mean
# Simulation0  16.093750  15.250000        19.620313
# Simulation0  20.281250  20.281250        28.507812
# Simulation0  12.375000  11.750000        19.378125
# Simulation0  32.187500  32.125000        36.435938
# Simulation0  23.250000  23.593750        28.054688
# ...                ...        ...              ...
# Simulation0  15.656250  15.312500        19.154688
# Simulation0  16.781250  15.906250        22.654688
# Simulation0  19.875000  19.625000        23.207812
# Simulation0  20.093750  19.593750        26.439062
# Round Mean   17.609875  17.323469        22.889855
#
# [1001 rows x 21 columns]

# %%
avg_contribution_graph(shared_sim)

# %%
metrics_of_interest_shared = pd.read_csv('metrics_of_interest_1.csv', index_col = 0)

# %%
player_round_average_contributions_shared = player_round_average_contributions(metrics_of_interest_shared, SIMS, NUM_PLAYERS, NUM_ROUNDS)

# %%
player_round_avg_contribution_graph(player_round_average_contributions_shared, NUM_ROUNDS, NUM_PLAYERS)

# %%
player_avg_bar_chart(player_round_average_contributions_shared, NUM_PLAYERS)

# %%
group_round_average_contribution_shared = group_round_average_contribution(metrics_of_interest_shared, NUM_GROUPS, NUM_ROUNDS, SIMS)

# %%
group_round_avg_contribution_graph(group_round_average_contribution_shared, NUM_ROUNDS, NUM_GROUPS)

# %%
group_avg_bar_chart(group_round_average_contribution_shared, NUM_GROUPS)

# %% [markdown]
# ### Split Endowment

# %%
SHARED = 0
split_sim = monte_carlo_simulation(SIMS)

# %%
split_sim
# Out:
#                 Round0     Round1     Round2     Round3    Round4    Round5  \
# Simulation0  24.843750  25.375000  29.062500  30.437500  30.46875  27.81250
# Simulation0  18.906250  19.875000  22.093750  21.093750  19.84375  19.12500
# Simulation0  26.000000  30.718750  30.875000  30.593750  29.75000  26.34375
# Simulation0  26.781250  27.656250  25.843750  27.593750  27.28125  26.00000
# Simulation0  18.718750  20.125000  20.437500  20.562500  20.34375  20.12500
# ...                ...        ...        ...        ...       ...       ...
# Simulation0  31.750000  33.531250  34.406250  34.531250  30.53125  30.40625
# Simulation0  18.281250  18.281250  18.343750  18.062500  18.65625  17.31250
# Simulation0  30.937500  30.000000  28.062500  25.125000  25.37500  23.84375
# Simulation0  17.375000  20.375000  22.031250  21.406250  20.28125  19.65625
# Round Mean   27.040844  28.391969  28.601063  28.193094  27.54475  26.77450
#
#                 Round6     Round7     Round8     Round9  ...    Round11  \
# Simulation0  28.218750  26.187500  24.875000  25.562500  ...  24.156250
# Simulation0  18.031250  17.156250  16.093750  15.156250  ...  13.281250
# Simulation0  25.843750  25.843750  25.125000  24.843750  ...  22.843750
# Simulation0  24.500000  24.093750  23.593750  22.812500  ...  21.562500
# Simulation0  19.843750  19.156250  18.625000  18.187500  ...  17.218750
# ...                ...        ...        ...        ...  ...        ...
# Simulation0  30.000000  30.125000  30.156250  29.562500  ...  27.625000
# Simulation0  16.687500  15.906250  14.718750  13.468750  ...  12.062500
# Simulation0  24.406250  23.968750  23.093750  22.406250  ...  20.687500
# Simulation0  18.906250  18.125000  17.375000  15.562500  ...  15.625000
# Round Mean   25.953969  25.065656  24.169937  23.290219  ...  21.662656
#
#               Round12    Round13    Round14    Round15   Round16    Round17  \
# Simulation0  21.90625  21.906250  21.468750  20.343750  20.68750  20.812500
# Simulation0  12.46875  11.687500  10.406250   9.750000   9.56250   9.437500
# Simulation0  22.12500  21.875000  21.593750  20.968750  20.25000  20.125000
# Simulation0  21.53125  21.718750  21.593750  20.843750  19.37500  20.062500
# Simulation0  16.93750  16.656250  16.281250  15.875000  15.46875  15.156250
# ...               ...        ...        ...        ...       ...        ...
# Simulation0  26.75000  26.000000  25.250000  24.437500  23.56250  23.343750
# Simulation0  11.53125  11.281250  11.437500  10.375000   9.87500   9.281250
# Simulation0  19.93750  19.187500  18.187500  18.000000  17.75000  18.031250
# Simulation0  15.46875  14.968750  13.468750  11.906250  12.93750  12.937500
# Round Mean   20.92575  20.219656  19.560844  18.951781  18.46800  18.063375
#
#                Round18    Round19  Simulation Mean
# Simulation0  20.875000  20.625000        24.528125
# Simulation0   8.781250   8.125000        14.756250
# Simulation0  19.718750  19.500000        24.435938
# Simulation0  17.937500  18.937500        23.117188
# Simulation0  14.843750  14.750000        17.857813
# ...                ...        ...              ...
# Simulation0  23.062500  22.875000        28.356250
# Simulation0   9.093750   9.062500        13.834375
# Simulation0  17.750000  16.250000        22.229688
# Simulation0  12.875000  12.718750        16.462500
# Round Mean   17.754062  17.480812        23.027748
#
# [1001 rows x 21 columns]

# %%
avg_contribution_graph(split_sim)

# %%
metrics_of_interest_split = pd.read_csv('metrics_of_interest_0.csv', index_col = 0)

# %%
player_round_average_contributions_split= player_round_average_contributions(metrics_of_interest_split, SIMS, NUM_PLAYERS, NUM_ROUNDS)

# %%
player_round_avg_contribution_graph(player_round_average_contributions_split, NUM_ROUNDS, NUM_PLAYERS)

# %%
player_avg_bar_chart(player_round_average_contributions_split, NUM_PLAYERS)

# %%
group_round_average_contribution_split = group_round_average_contribution(metrics_of_interest_split, NUM_GROUPS, NUM_ROUNDS, SIMS)

# %%
group_round_avg_contribution_graph(group_round_average_contribution_split, NUM_ROUNDS, NUM_GROUPS)

# %%
group_avg_bar_chart(group_round_average_contribution_split, NUM_GROUPS)
